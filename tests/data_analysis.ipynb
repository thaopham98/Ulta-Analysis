# %% [markdown]
# ## Setup

# %%
import pandas as pd
from IPython.display import HTML, display
# from PIL import Image
# from io import BytesIO

# %%
from color_analysis_func import show_swatches

# %% [markdown]
# ## Load Data

# %%
# df = pd.read_csv(r"..\data\processed_data\test\blushes\cleaned\cleaned_single_blush.csv", encoding='utf-8-sig')
df = pd.read_csv(r"..\data\raw\foundation\20260803T213850Z\variants.csv", encoding="utf-8-sig")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           183 non-null    str
#  1   sku_id               183 non-null    int64
#  2   variant_type         183 non-null    str
#  3   variant_name         183 non-null    str
#  4   variant_description  182 non-null    str
#  5   variant_url          183 non-null    str
#  6   list_price           183 non-null    float64
#  7   sale_price           72 non-null     float64
#  8   size_text            183 non-null    str
#  9   availability         183 non-null    str
#  10  swatch_image_url     183 non-null    str
#  11  variant_image_url    183 non-null    str
#  12  ingredient_set_id    183 non-null    str
# dtypes: float64(2), int64(1), str(10)
# memory usage: 18.7 KB

# %%
### Blushes
# ## Renaming
# df.rename(
#     columns={
#             "effective_price":"price", 
#             "normalized_size_g_ml": "metric_size", 
#             "size_value":"imperial_size"
#         }, 
#     inplace=True
# )

# ## Dropping 
# df.drop(columns="size_unit", inplace=True)

# %%
### Foundation
df.head()
# Out:
#        product_id   sku_id variant_type    variant_name  \
# 0  pimprod2057355  2651970        color   0N1 Alabaster
# 1  pimprod2057355  2651971        color       1C0 Shell
# 2  pimprod2057355  2651972        color   1C1 Cool Bone
# 3  pimprod2057355  2651973        color   1N0 Porcelain
# 4  pimprod2057355  2651974        color  1N1 Ivory Nude
#
#                      variant_description  \
# 0       lightest with neutral undertones
# 1   very light with cool pink undertones
# 2  light with cool rosy-peach undertones
# 3     very light with neutral undertones
# 4    light with neutral peach undertones
#
#                                          variant_url  list_price  sale_price  \
# 0  https://www.ulta.com/p/double-wear-stay-in-pla...        52.0         NaN
# 1  https://www.ulta.com/p/double-wear-stay-in-pla...        52.0         NaN
# 2  https://www.ulta.com/p/double-wear-stay-in-pla...        52.0         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1363 entries, 0 to 1362
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1363 non-null   str
#  1   sku_id               1363 non-null   int64
#  2   variant_name         1363 non-null   str
#  3   variant_description  1027 non-null   str
#  4   variant_url          1363 non-null   str
#  5   swatch_image_url     1363 non-null   str
#  6   variant_image_url    1363 non-null   str
#  7   ingredient_set_id    1333 non-null   str
#  8   brand                1363 non-null   str
#  9   product_name         1363 non-null   str
#  10  imperial_size        1363 non-null   float64
#  11  price                1363 non-null   float64
#  12  metric_size          1360 non-null   float64
#  13  price_per_g_ml       1360 non-null   float64
# dtypes: float64(4), int64(1), str(9)
# memory usage: 149.2 KB
